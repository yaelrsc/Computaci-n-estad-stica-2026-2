# %%
import matplotlib.pyplot as plt
plt.style.use('default')

# %%
import torch
from monte_carlo import MonteCarloIntegration
from monte_carlo_variance_reduction import  PiMonteCarlo, AntitheticMonteCarloIntegration, StratifiedMonteCarloIntegration, NormalMultivariateMonteCarlo
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # **Integración Monte Carlo**

# %%
def F(x):

    return torch.exp(x**2)

# %%
mc_int = MonteCarloIntegration(F)
inte, ci, var = mc_int.compute_integral(2, 3, n=1000000)
# Out:
# integral: 1430.2406, Confidence Interval: (1426.5193, 1433.9620), Var: 3.6050

# %%
amc_int = AntitheticMonteCarloIntegration(F, device=device)
inte, ci, var = amc_int.compute_integral(2, 3, n=1000000)
# Out:
# integral: 1426.9617, Confidence Interval: (1425.0633, 1428.8600), Var: 0.9381

# %%
amc_int = AntitheticMonteCarloIntegration(F, device=device)
inte, ci, var = amc_int.compute_integral(-2, -3, n=1000000)
# Out:
# integral: -1428.6851, Confidence Interval: (-1426.7845, -1430.5856), Var: 0.9403

# %%
mc_int = MonteCarloIntegration(F)
mc_int.compute_integral(-1, 1, n=1000000)
# Out:
# integral: 2.9262, Confidence Interval: (2.9244, 2.9281), Var: 0.0000
# (2.926220655441284,
#  (2.9243611409331747, 2.9280801699493937),
#  9.001250152952168e-07)

# %%
amc_int = AntitheticMonteCarloIntegration(F, device=device)
amc_int.compute_integral(-1, 1, n=1000000)
# Out:
# integral: 2.9238, Confidence Interval: (2.9219, 2.9256), Var: 0.0000
# (2.9237709045410156,
#  (2.9219132509060652, 2.925628558175966),
#  0.0009477997422218323)

# %%
smc_int = StratifiedMonteCarloIntegration(F, device=device)
_, _, _ = smc_int.compute_integral(2, 3, n=1000000)
# Out:
# integral: 1428.1875, Confidence Interval: (1427.9448, 1428.4302), Var: 0.0153

# %% [markdown]
# # **Aproximación de $\pi$**

# %%
PI_MC = PiMonteCarlo(device=device)

pi_mc, var_mc = PI_MC.compute_pi(n=10000000, decimals=10)
# Out:
# Estimación de π (MC): 3.1403803825
# Varianza estimada: 0.0000002700

# %%
pi_cv, var_cv = PI_MC.compute_pi_control(n=10000000, decimals=10)
# Out:
# Estimación de π (Control Variate): 3.1416025162
# Varianza estimada: 0.0000000652

# %%
pi_cv, var_cv = PI_MC.compute_pi_conditional(n=10000000, decimals=10)
# Out:
# Estimación de π (Conditional MC): 3.1417639256
# Varianza estimada: 0.0000000797

# %%
pi_cv, var_cv = PI_MC.compute_pi_stratified(n=10000000, decimals=10)
# Out:
# Estimación de π (Stratified MC): 3.1410527229
# Varianza estimada: 0.0000000192

# %%
PI_MC.compare_variances(n=1000000)
# Out:
# Estimación de π (MC): 3.1383
# Varianza estimada: 0.0000
# Estimación de π (Control Variate): 3.1407
# Varianza estimada: 0.0000
# Estimación de π (Conditional MC): 3.1398
# Varianza estimada: 0.0000
# Estimación de π (Stratified MC): 3.1416
# Varianza estimada: 0.0000

# %% [markdown]
# # **Monte Carlo Multivariado**

# %%
mu = torch.tensor([0.5, -0.3])

Sigma = torch.tensor([
    [1.0, 0.6],
    [0.6, 1.5]
])

def G(X):
    return X[:, 0]**2 + X[:, 1]**2-2.5 * X[:, 0]*X[:, 1]

# %%
mc_normal = NormalMultivariateMonteCarlo(mu, Sigma, G, device=device)
mc_normal.compare_variances(n=1000000)
# Out:
# Esperanza estimada (MC): 1.708520
# Varianza estimada: 0.000009
# Esperanza estimada (Antithetic MC): 1.716108
# Varianza estimada: 0.000005

# %%
def G(X):
    return torch.exp(-X[:, 0]**2-X[:, 1]**2)
    
mc_normal = NormalMultivariateMonteCarlo(mu, Sigma, G, device=device)

mc_normal.compare_variances(n=1000000)
# Out:
# Esperanza estimada (MC): 0.263661
# Varianza estimada: 0.000000
# Esperanza estimada (Antithetic MC): 0.263658
# Varianza estimada: 0.000000
