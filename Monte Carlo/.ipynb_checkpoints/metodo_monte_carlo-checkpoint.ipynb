# %%
import matplotlib.pyplot as plt
plt.style.use('default')

# %%
from monte_carlo import MonteCarloIntegration, EmpiricalCDF, EmpiricalPDF, ParametricVaRCVaR
import torch

# %% [markdown]
# # **Integración Monte Carlo**

# %%
def f(x):
    return x**2
    
mc_int = MonteCarloIntegration(f)
inte, conf_int, var = mc_int.compute_integral(0, 1, n=1000000)
# Out:
# integral: 0.3333, Confidence Interval: (0.3327, 0.3339), Var: 0.0000

# %%
def f(x):
    return x**2

mc_int = MonteCarloIntegration(f)
inte, conf_int, var = mc_int.compute_integral(-1, 1, n=1000000)
# Out:
# integral: 0.6669, Confidence Interval: (0.6657, 0.6680), Var: 0.0000

# %%
def f(x):
    return x**2-1  

mc_int = MonteCarloIntegration(f)
inte, conf_int, var = mc_int.compute_integral(-1, 1, n=1000000)
# Out:
# integral: -1.3332, Confidence Interval: (-1.3344, -1.3321), Var: 0.0000

# %%
device =  torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # **Función de Distribución Empírica**

# %%
norm = torch.distributions.Normal(0,1)
n_sample = 10000
data = norm.sample((n_sample,))
norm_ecdf = EmpiricalCDF(data)
x = torch.Tensor([0.0])
integral, conf_int = norm_ecdf.compute(x)
# Out:
# ECDF: 0.5096, Band: (0.4960, 0.5232)

# %%
x = torch.Tensor([0.0, -1.0, 1.0])
integral, conf_int = norm_ecdf.compute(x)
integral
# Out:
# tensor([0.5096, 0.1600, 0.8479], device='cuda:0')

# %%
norm_ecdf.plot(-3.,3.,n_points=100000)

# %%
unif = torch.distributions.Uniform(0,1)
n_sample = 100000
data = unif.sample((n_sample,))
unif_ecdf = EmpiricalCDF(data)
unif_ecdf.plot(-1.0, 2.0, n_points=1000)

# %%
exp = torch.distributions.Exponential(1.0)
n_sample = 100000
data = exp.sample((n_sample,))
exp_ecdf = EmpiricalCDF(data)
exp_ecdf.plot(-1.0, 1.0, n_points=1000)

# %% [markdown]
# # **Función de Densidad Empírica**

# %%
exp_pdf = EmpiricalPDF(exp)
exp_pdf.plot(0.0,5.0,n_sim=10000,n_groups=100)

# %%
norm_pdf = EmpiricalPDF(norm)
norm_pdf.plot(-5.0, 5.0, n_sim=10000, n_groups=200)

# %%
norm_pdf.plot(-5.0, 5.0, n_sim=10000, n_groups=100, h=1e-5)

# %%
norm_pdf.plot(-5.0, 5.0, n_sim=10000, n_groups=100, h=0.8)

# %%
gam = torch.distributions.Gamma(2.0,1.0)
gam_pdf = EmpiricalPDF(gam)
gam_pdf.plot(0.0, 5.0, n_sim=20000, n_groups=100)

# %%
gam = torch.distributions.Gamma(2.0,1.0)
gam_pdf = EmpiricalPDF(gam)
gam_pdf.plot(0.0, 5.0, n_sim=20000, n_groups=100, h=0.095)

# %%
t = torch.distributions.StudentT(2)
t_pdf = EmpiricalPDF(t)
t_pdf.plot(-10, 10, n_sim=10000, n_groups=200)

# %% [markdown]
# # **VaR y CVaR**

# %%
var_cvart = ParametricVaRCVaR(t)
VaR, CI = var_cvart.compute_VaR(n=1000000)
# Out:
# VaR : -2.9150,
# Conf. Int: (-2.9296, -2.9005)

# %%
CVaR, CI = var_cvart.compute_CVaR(n=1000000)
# Out:
# CVaR : -6.1815,
# Conf. Int: (-6.2930, -6.0700)

# %%
df = 5.184055350346162
loc = 0.002202628761248923
scale = 0.02533817014977337

t = torch.distributions.StudentT(df, loc, scale)

var_cvart = ParametricVaRCVaR(t)

VaR, CI = var_cvart.compute_VaR(n=1000000)
# Out:
# VaR : -0.0485,
# Conf. Int: (-0.0487, -0.0483)

# %%
CVaR, CI = var_cvart.compute_CVaR(n=1000000)
# Out:
# CVaR : -0.0700,
# Conf. Int: (-0.0706, -0.0694)
